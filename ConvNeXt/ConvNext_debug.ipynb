# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Scania_Thesis/ConvNext
# !ls
# Out:
# /content/drive/MyDrive/Scania_Thesis/ConvNext
# checkpoint_base.pth   checkpoint.pth	    ConvNext_test.py   README.md
# checkpoint_large.pth  ConvNext_debug.ipynb  ConvNext_train.py  wandb

# %%
# !pip install wandb
# !wandb login
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 15.6 MB/s
# ...
#      |████████████████████████████████| 145 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 181 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=d49ea4a72346d13f2e1979f331c25cef8bbe97c9398c6a8ed719a501a23a4677
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python ConvNext_train.py --data_path /content/drive/MyDrive/Scania_Thesis/Final_Dataset_Clean --output_dir "/content/drive/MyDrive/Scania_Thesis/ConvNext/checkpoint.pth"
# Out:
# wandb: Currently logged in as: talhabilal. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /content/drive/MyDrive/Scania_Thesis/ConvNext/wandb/run-20220603_180945-3c0adess
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dark-wind-8
# wandb: ⭐️ View project at https://wandb.ai/talhabilal/ConvNext
# wandb: 🚀 View run at https://wandb.ai/talhabilal/ConvNext/runs/3c0adess
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ConvNeXt(
#   (features): Sequential(
# ...

# %%
# !python ConvNext_test.py --data_path /content/drive/MyDrive/Scania_Thesis/Final_Dataset_Clean --weights "/content/drive/MyDrive/Scania_Thesis/ConvNext/checkpoint.pth"
# Out:
# wandb: Currently logged in as: talhabilal. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /content/drive/MyDrive/Scania_Thesis/ConvNext/wandb/run-20220605_164324-29rsok7w
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pleasant-glitter-10
# wandb: ⭐️ View project at https://wandb.ai/talhabilal/ConvNext
# wandb: 🚀 View run at https://wandb.ai/talhabilal/ConvNext/runs/29rsok7w
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
