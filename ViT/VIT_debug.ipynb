# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Scania_Thesis/VIT/VIT/
# !ls
# Out:
# /content/drive/MyDrive/Scania_Thesis/VIT/VIT
# checkpoint.pth	README.md  VIT_debug.ipynb  VIT_test.py  VIT_train.py  wandb

# %%
# !pip install wandb
# !wandb login
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 13.7 MB/s
# ...
#      |████████████████████████████████| 181 kB 71.0 MB/s
# ...
#      |████████████████████████████████| 145 kB 67.3 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=3fafff193df42e8f922a24d12d8b744374cd52ea0ce56c71d10e812171dd7f53
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python VIT_train.py --data_path /content/drive/MyDrive/Scania_Thesis/Final_Dataset_Clean --output_dir "/content/drive/MyDrive/Scania_Thesis/VIT/VIT/checkpoint.pth"
# Out:
# wandb: Currently logged in as: talhabilal. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /content/drive/MyDrive/Scania_Thesis/VIT/VIT/wandb/run-20220517_121049-25qa0osv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run drawn-plant-6
# wandb: ⭐️ View project at https://wandb.ai/talhabilal/VIT
# wandb: 🚀 View run at https://wandb.ai/talhabilal/VIT/runs/25qa0osv
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VisionTransformer(
# ...

# %%
# !python VIT_test.py --data_path /content/drive/MyDrive/Scania_Thesis/Final_Dataset_Clean --weights "/content/drive/MyDrive/Scania_Thesis/VIT/VIT/checkpoint.pth"
# Out:
# wandb: Currently logged in as: talhabilal. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /content/drive/MyDrive/Scania_Thesis/VIT/VIT/wandb/run-20220518_082838-13d1xx4e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run charmed-sea-8
# wandb: ⭐️ View project at https://wandb.ai/talhabilal/VIT
# wandb: 🚀 View run at https://wandb.ai/talhabilal/VIT/runs/13d1xx4e
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
