# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Scania_Thesis/Efficenit_Net/
# !ls
# Out:
# /content/drive/MyDrive/Scania_Thesis/Efficenit_Net
# EfficeintNet_debug.ipynb  EfficeintNet_train.py
# EfficeintNet_test.py	  README.md

# %%
# !pip install wandb
# !wandb login
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 145 kB 77.5 MB/s
# ...
#      |████████████████████████████████| 181 kB 85.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.4 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=706dc719542ff1cde720ba6c4ff3e8b2a876cfaccbd0a75f1262050218142372
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python EfficeintNet_train.py --data_path /content/drive/MyDrive/Scania_Thesis/Mini-test --output_dir "/content/drive/MyDrive/Scania_Thesis/Efficenit_Net/checkpoint.pth"
# Out:
# wandb: Currently logged in as: talhabilal. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /content/drive/MyDrive/Scania_Thesis/Efficenit_Net/wandb/run-20220516_173902-2ycaupsg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run silvery-resonance-7
# wandb: ⭐️ View project at https://wandb.ai/talhabilal/EfficeintNet
# wandb: 🚀 View run at https://wandb.ai/talhabilal/EfficeintNet/runs/2ycaupsg
# Epoch 0/49
# ----------
# train Loss: 0.6706 Acc: 0.7910
# val Loss: 0.9327 Acc: 0.7547
#
# Epoch 1/49
# ----------
# train Loss: 0.5081 Acc: 0.8194
# val Loss: 0.8435 Acc: 0.6981
#
# Epoch 2/49
# ----------
# train Loss: 0.4384 Acc: 0.8485
# val Loss: 0.8788 Acc: 0.6792
#
# Epoch 3/49
# ----------
# train Loss: 0.4334 Acc: 0.8473
# val Loss: 0.8140 Acc: 0.7358
#
# Epoch 4/49
# ----------
# train Loss: 0.4254 Acc: 0.8490
# val Loss: 0.8364 Acc: 0.7358
#
# Epoch 5/49
# ----------
# ...
